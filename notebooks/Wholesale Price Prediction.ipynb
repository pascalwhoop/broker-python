# %%
import os, numpy as np, tensorflow as tf, keras, sklearn, pandas as pd

from agent_components.wholesale.mdp import parse_wholesale_file
from notebooks.helpers import *

# %%
os.chdir('..')
os.getcwd()
# Out:
# '/home/pascalwhoop/Documents/Code/University/powerTAC/python-agent'

# %%
path_files = '../powertac-tools/logtool-examples/data'
path_files = os.path.abspath(path_files)

# %%
files = os.listdir(path_files)
files = [os.path.join(path_files, f) for f in files if "marketprices" in f]
files.sort()

# %%
def get_data_from(file_):
    with open(file_) as f:
        return parse_wholesale_file(f)
    
wholesale_data = get_data_from(files[0])
wholesale_data = np.array([row[3:] for row in wholesale_data])

# %%
closing_prices = pd.DataFrame(wholesale_data[:14*7,-5:,1])
closing_prices.plot(figsize=FIGSIZE)

# %%
final_prices = wholesale_data[:,-1,1]
